# %%
import osmnx as ox
import networkx as nx
ox.config(log_console=True, use_cache=True)
# define the start and end locations in latlng
start_latlng = (45.267136,19.833549)
end_latlng = (45.267136,19.843549)
# location where you want to find your route
# place     = 'Novi Sad, Serbia'
# find shortest route based on the mode of travel
mode      = 'drive'        # 'drive', 'bike', 'walk'
# find shortest path based on distance or time
optimizer = 'time'        # 'length','time'
# create graph from OSM within the boundaries of some 
# geocodable place(s)
point = 45.267136, 19.833549
dist = 1000
graph = ox.graph_from_point(point, dist=dist, network_type='drive', simplify=False) 
# find the nearest node to the start location
graph = ox.add_edge_speeds(graph)
graph = ox.add_edge_travel_times(graph)
# Out:
# c:\program files\python38\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# C:\Users\Korisnik\AppData\Roaming\Python\Python38\site-packages\osmnx\utils.py:192: UserWarning: The `utils.config` function is deprecated and will be removed in a future release. Instead, use the `settings` module directly to configure a global setting's value. For example, `ox.settings.log_console=True`.
#   warnings.warn(

# %%
# orig_node = ox.nearest_nodes(graph, start_latlng[1],start_latlng[0])

orig_node = ox.nearest_nodes(graph, 19.833549,5.267136)

# find the nearest node to the end location
print(orig_node)
# Out:
# 7563894200

# %%
# dest_node = ox.nearest_nodes(graph, end_latlng[1],end_latlng[0])

dest_node = ox.nearest_nodes(graph, 19.83587449191593,45.264838442127214)

print(dest_node)
# Out:
# 6804991743

# %%
#  find the shortest path
shortest_route = nx.shortest_path(graph,
                                  orig_node,
                                  dest_node,
                                  weight=optimizer)
print(shortest_route)
# Out:
# [7563894200, 3839157779, 1453875474, 7563894201, 3839157785, 3839157787, 7563894224, 4230087000, 7563894207, 3839157795, 3839157799, 3839157800, 8263960911, 4230087002, 1608789227, 7563894212, 4813289737, 568165734, 3856092278, 3856092279, 1453875485, 3856092280, 6811899650, 9498581141, 1104703069, 3652964207, 1229948825, 60345126, 4949365109, 1229461794, 8263988185, 3652964209, 60570745, 60701344, 3705539013, 1229618974, 6804991744, 6804991745, 1229619076, 1574842475, 1574842474, 6804991747, 6804991746, 6804991743]

# %%
shortest_route_map = ox.plot_route_folium(graph, shortest_route)
shortest_route_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...
